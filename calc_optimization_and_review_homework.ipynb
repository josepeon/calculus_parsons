# %% [markdown]
# <a href="https://colab.research.google.com/github/josepeon/calculus_parsons/blob/main/calc_optimization_and_review_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sympy as sy

# %% [markdown]
# 1. A cardiac monitor is used to measure the heart rate of a patient
# after surgery. It compiles the number of heartbeats after t minutes.
# When the data in the table are graphed, the slope of the
# tangent line represents the heart rate in beats per minute.
#
# | t (min) | Heartbeats |
# | ------  | ---------  |
# | 36.  |  2530 |
# | 38  | 2661 |
# | 40  | 2806 |
# | 42 | 2948 |
# | 44 | 3080 |
#
# Use the data to estimate the patient's heart rate over each interval.  What do you conclude?

# %%
data = {"t_min": [36, 38, 40, 42, 44], "heartbeats": [2530, 2661, 2806, 2948, 3080]}
df = pd.DataFrame(data)
df
# Out:
#    t_min  heartbeats
# 0     36        2530
# 1     38        2661
# 2     40        2806
# 3     42        2948
# 4     44        3080

# %%
df["heart_rate"] = df["heartbeats"].diff() / df["t_min"].diff()
df
# Out:
#    t_min  heartbeats  heart_rate
# 0     36        2530         NaN
# 1     38        2661        65.5
# 2     40        2806        72.5
# 3     42        2948        71.0
# 4     44        3080        66.0

# %%
avg_rate = df["heart_rate"].mean()
avg_rate
# Out:
# np.float64(68.75)

# %%
#Average estimated heart rate is 68.75 bpm

# %% [markdown]
# 2. The displacement of a particle moving in a straight line is given by the function $s(t) = \frac{1}{t^2}$. Find the velocity and acceleration of the particle at times $t = 0, 1, 2, 3, 4$.  Make a table with your results.

# %%
t = sy.Symbol('t')
s = 1 / t**2

# %%
v = sy.diff(s, t)
a = sy.diff(v, t)
times = [1, 2, 3, 4]

# %%
data = []
for time in times:
    data.append([time, s.subs(t, time), v.subs(t, time), a.subs(t, time)])

# %%
df = pd.DataFrame(data, columns=["t", "s(t)", "v(t)", "a(t)"])
df
# Out:
#    t  s(t)   v(t)   a(t)
# 0  1     1     -2      6
# 1  2   1/4   -1/4    3/8
# 2  3   1/9  -2/27   2/27
# 3  4  1/16  -1/32  3/128

# %% [markdown]
# 3. A warm bowl of soup is placed in a cold room.  Sketch the graph of the temperature of the soup as a function of time.  How does the initial rate of change compare to that 2 hours from now?

# %% [markdown]
# ![IMG_9896.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# 4. The `DataFrame` below contains estimated percentage of the population of Europe using cell phones.
#
# - Use the data to determine the average rate of change from 1998 to 2000.
# - Estimate the instantaneous rate of change in 2000.

# %%
data = {'Year': [i for i in range(1998, 2004)], 'P': [28, 39, 55, 68, 77, 83]}
df = pd.DataFrame(data)
df
# Out:
#    Year   P
# 0  1998  28
# 1  1999  39
# 2  2000  55
# 3  2001  68
# 4  2002  77
# 5  2003  83

# %%
avg_rate = (55 - 28) / (2000 - 1998)
inst_rate = (68 - 39) / (2001 - 1999)
print(avg_rate, inst_rate)
# Out:
# 13.5 14.5

# %% [markdown]
# 5. Find the derivative of the given function.
#
#  - $f(x) = \frac{1}{2}x^6 - 4x^4 + x$
#  - $g(x) = \frac{1}{5}(x^5 + 8)$
#  - $h(x) = \frac{x^2 + 4x + 4}{\sqrt{x}}$
#  - $p(x) = \sqrt[5]{x} + 6\sqrt{x^6}$

# %%
import sympy as sy

# %%
x = sy.Symbol('x')

# %%
def h(x): return (x**2 + 4*x + 4)/(x**(1/2))

# %%
sy.diff(h(x), x)
# Out:
# -0.5*(x**2 + 4*x + 4)/x**1.5 + (2*x + 4)/x**0.5

# %% [markdown]
# 6. Write an equation for the line tangent to $y = 2x\sin(x)$ at $(\pi/2, \pi)$. Plot the tangent line and the original function together.

# %%
x = sy.Symbol('x')
def f(x): return 2*x*sy.sin(x)
def tan(x): return 2*(x - sy.pi/2) + sy.pi
sy.plot(x, f(x))
sy.plot(x, tan(x))

# %%
def f(x): return 2*x*np.sin(x)
def tan(x): return 2*(x - np.pi/2) + np.pi
x = np.linspace(0, 3, 100)
plt.plot(x, f(x))
plt.plot(x, tan(x))

# %% [markdown]
# 7. For each function below, plot the function and find all critical values for on the given interval.  Identify these critical points as *minimum*, *maximum*, or *neither*.   Is there a point you would say is the *absolute maximum*?  An *absolute minimum*?

# %% [markdown]
# 1. $f(x) = x^3 - 3x + 1$ on $[0, 3]$.
# 2. $f(x) = 2x^3 - 3x^2 - 12x + 1$ on $[-2, 3]$.
# 3. $f(x) = 2\cos(x) + \sin(2x)$ on $[0, \pi/2]$.

# %% [markdown]
# 8. Read through the examples in OpenStax chapter 4.7 [here](https://openstax.org/books/calculus-volume-1/pages/4-7-applied-optimization-problems).  Examine the solutions for the problems that have them, and skim through the text.  Answer the following questions:
#
# - When you find the maximum for an optimization problem, why do you need to check the sign of the derivative around the critical points?
# - Why do you need to check the endpoints for optimization problems?
# - True or False. For every continuous nonlinear function, you can find the value 𝑥 that maximizes the function.
# - True or False. For every continuous nonconstant function on a closed, finite domain, there exists at least one 𝑥 that minimizes or maximizes the function.

# %% [markdown]
# - Because a critical point could be a maximum, minimum, or neither.
# By checking whether f’(x) changes from positive to negative or negative to positive, we determine if it’s a local maximum or minimum.
# - Because on a closed interval, absolute maxima or minima might occur at the boundaries
# - False. A continuous nonlinear function can still increase or decrease forever
# - True. This is guaranteed by the Extreme Value Theorem

# %% [markdown]
# 9. You are constructing a cardboard box with the dimensions 2 m by 4 m. You then cut equal-size squares from each corner so you may fold the edges. What are the dimensions of the box with the largest volume?
#
# ![](https://openstax.org/resources/76141d03435531db0db595ea9036682599489563)

# %% [markdown]
# 10. Two poles are connected by a wire that is also connected to the ground. The first pole is 20 ft tall and the second pole is 10ft tall. There is a distance of 30 ft between the two poles. Where should the wire be anchored to the ground to minimize the amount of wire needed?
#
# ![](https://openstax.org/resources/b552f9631ff58624c44af7691ed7dae547f26758)

# %%
def l(x): return ((400 - (30 - x)**2) + (100 - x**2))**(1/2)
x = sy.Symbol('x')

# %%
dy = sy.diff(l(x), x)

# %%
eq = sy.Eq(dy, 0)

# %%
eq
# Out:
# Eq((30.0 - 2.0*x)/(-x**2 - (30 - x)**2 + 500)**0.5, 0)

# %%
sy.solve(eq, x)
# Out:
# [15.0000000000000]
